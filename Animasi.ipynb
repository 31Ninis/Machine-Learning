# %% [markdown]
# <a href="https://colab.research.google.com/github/31Ninis/Machine-Learning/blob/main/Animasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
ani=pd.read_csv('Animation.csv')
ani.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13631 entries, 0 to 13630
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   animeID          13631 non-null  int64
#  1   name             13631 non-null  object
#  2   source           13631 non-null  object
#  3   producers        7414 non-null   object
#  4   genre            13569 non-null  object
#  5   studio           8369 non-null   object
#  6   episodes         13349 non-null  float64
#  7   airing           13631 non-null  bool
#  8   rank             13631 non-null  int64
#  9   popularity       13631 non-null  int64
#  10  members          13631 non-null  int64
#  11  favorites        13631 non-null  int64
#  12  reviewers        13631 non-null  int64
#  13  Animation_score  13518 non-null  float64
# dtypes: bool(1), float64(2), int64(6), object(5)
# memory usage: 1.4+ MB

# %%
ani.head(10)
# Out:
#    animeID                             name    source             producers  \
# 0        1                     Cowboy Bebop  Original         Bandai Visual
# 1        5  Cowboy Bebop: Tengoku no Tobira  Original               Sunrise
# 2        6                           Trigun     Manga  Victor Entertainment
# 3        7               Witch Hunter Robin  Original         Bandai Visual
# 4        8                   Bouken Ou Beet     Manga              TV Tokyo
# 5       16             Hachimitsu to Clover     Manga                 Genco
# 6       17       Hungry Heart: Wild Striker     Manga                   NaN
# 7       18           Initial D Fourth Stage     Manga           OB Planning
# 8       19                          Monster     Manga                   VAP
# 9       20                           Naruto     Manga              TV Tokyo
#
#            genre            studio  episodes  airing  rank  popularity  \
# ...

# %%
#memisahkan atribut dngn label
X = ani[['animeID','name','source','producers','genre','studio','episodes','rank','popularity','members','favorites','reviewers','Animation_score']] #atribut
y = ani['airing'] #label

#membagi data set menjadi data latih dan dta uji
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=123)

# %%
from sklearn.impute import SimpleImputer

# Membuat objek imputer
imputer = SimpleImputer(strategy='mean')

# Mengisi nilai kosong dalam data latih
final_train_imputed = pd.DataFrame(imputer.fit_transform(final_train), columns=final_train.columns)

# Melatih model menggunakan data latih yang sudah diimputasi
tree_model.fit(final_train_imputed, y_train)

# Mengisi nilai kosong dalam data uji dengan nilai rata-rata yang sama dari data latih
final_test_imputed = pd.DataFrame(imputer.transform(final_test), columns=final_test.columns)

# Menguji model menggunakan data uji yang sudah diimputasi
accuracy = tree_model.score(final_test_imputed, y_test)
print("Akurasi model pada data uji:", accuracy)
# Out:
# Akurasi model pada data uji: 0.9890029325513197

# %%
from sklearn.tree import export_graphviz
import graphviz

# Menghasilkan visualisasi decision tree
dot_data = export_graphviz(tree_model,
                           out_file=None,
                           feature_names=final_train.columns,
                           class_names=['Not Airing', 'Airing'],  # Sesuaikan dengan kelas yang tepat
                           rounded=True,
                           filled=True)

# %%
import graphviz

# Membaca isi file DOT
with open("anime_tree.dot") as f:
    dot_graph = f.read()

# Membuat objek graph dari data dot
source = graphviz.Source(dot_graph)

# Menampilkan visualisasi decision tree
source.view()
# Out:
# 'Source.gv.pdf'
